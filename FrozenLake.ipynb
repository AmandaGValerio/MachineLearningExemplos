# %%
import gym
import numpy as np

# %%
# 1. Load Environment and Q-table structure
env = gym.make('FrozenLake-v0')
Q = np.zeros([env.observation_space.n,env.action_space.n])
# env.observation.n, env.action_space.n gives number of states and action in env loaded

# %%
# 2. Parameters of Q-learning
eta = .628
gma = .9
epis = 75000
rev_list = [] # rewards per episode calculate

# %%
# 3. Q-learning Algorithm
for i in range(epis):
    # Reset environment
    s = env.reset()
    rAll = 0
    d = False
    j = 0
    #The Q-Table learning algorithm
    while j < 99:
        #env.render()
        j+=1
        # Choose action from Q table
        a = np.argmax(Q[s,:] + np.random.randn(1,env.action_space.n)*(1./(i+1)))
        #Get new state & reward from environment
        s1,r,d,_ = env.step(a)
        #Update Q-Table with new knowledge
        Q[s,a] = Q[s,a] + eta*(r + gma*np.max(Q[s1,:]) - Q[s,a])
        rAll += r
        s = s1
        if d == True:
            break
    rev_list.append(rAll)
    #env.render()
print("fim")
# Out:
# fim

# %%
print("Reward Sum on all episodes " + str(sum(rev_list)/epis))
print("Ultima recompensa: " + str(rev_list[epis-1]))
print("Final Values Q-Table")
print(Q)
# Out:
# Reward Sum on all episodes 0.5164933333333334
# Ultima recompensa: 1.0
# Final Values Q-Table
# [[1.61470855e-01 5.36708669e-04 5.86437343e-04 6.01738190e-04]
#  [2.26016538e-04 2.05276535e-04 2.35686329e-04 6.16593357e-02]
#  [1.78191778e-04 1.86787792e-04 1.28671329e-04 2.65538080e-02]
#  [2.26200390e-05 4.27933978e-05 1.78014755e-05 1.11996676e-02]
#  [3.20551655e-01 1.13803156e-03 6.15922217e-04 6.04451668e-04]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00]
#  [3.09010390e-02 3.00327813e-06 2.08346338e-06 9.28206464e-07]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00]
#  [6.09295480e-04 1.00695900e-03 1.60725434e-03 5.31435894e-01]
#  [0.00000000e+00 6.41234091e-01 1.64374696e-03 1.93564406e-03]
#  [2.48974755e-01 0.00000000e+00 3.03293356e-04 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 2.78739238e-03 7.44552548e-01 2.26957463e-03]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 9.66624325e-01]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00]]

# %%
s = env.reset()
rAll = 0
d = False
j = 0
while j < 99:
        env.render()
        j+=1
        # Choose action from Q table
        a = np.argmax(Q[s,:] + np.random.randn(1,env.action_space.n)*(1./(i+1)))
        #Get new state & reward from environment
        s1,r,d,_ = env.step(a)
        #Update Q-Table with new knowledge
        #Q[s,a] = Q[s,a] + eta*(r + gma*np.max(Q[s1,:]) - Q[s,a])
        rAll += r
        s = s1
        if d == True:
            break
env.render()
env.reset()
env.close()
# Out:
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
